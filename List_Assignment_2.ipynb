# %% [markdown]
# <a href="https://colab.research.google.com/github/ik-GH/python-assignment-2/blob/main/List_Assignment_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1.Create a list of 5 employee names and add a new employee using append().

# %%
employee = ["Rahul", "Anita", "Kiran", "Sneha", "Vikram"]
employee.append('ikram')
print(employee)
# Out:
# ['Rahul', 'Anita', 'Kiran', 'Sneha', 'Vikram', 'ikram']

# %% [markdown]
# 2. Create a list of account numbers and add three new account numbers using extend().

# %%
Account_numbers = [85000, 120000, 45000, 95000, 275000]
Account_numbers.extend([12345,56789,9876])
Account_numbers
# Out:
# [85000, 120000, 45000, 95000, 275000, 12345, 56789, 9876]

# %% [markdown]
# 3.Insert a transaction amount at index 3 in a list.

# %%
Transaction = [12345, 2345, 3456, 4567, 7899]
Transaction.insert(3,9999)
Transaction
# Out:
# [12345, 2345, 3456, 9999, 4567, 7899]

# %% [markdown]
# 4.Remove the last item from a list using pop().

# %%
bank_branches = ["MG Road", "indiranagar", "white field", "Maratahalli", "Electronic city"]
bank_branches.pop(-1)
bank_branches
# Out:
# ['MG Road', 'indiranagar', 'white field', 'Maratahalli']

# %% [markdown]
# 5.Remove the customer "Rahul" from a customer list using remove().

# %%
customer = ["Rahul", "Anita", "Kiran", "Sneha", "Vikram"]
customer.remove("Rahul")
customer
# Out:
# ['Anita', 'Kiran', 'Sneha', 'Vikram']

# %% [markdown]
# 6. Count how many times the account type "savings" appers in a list using count().

# %%
account_types = ["savings", "current", "savings", "loan", "savings"]
account_types.count("savings")
# Out:
# 3

# %% [markdown]
# 7. Find the index of "Current" in a list of account types using index().

# %%
account_types = ["savings", "current", "savings", "loan",]
account_types.index("current")
# Out:
# 1

# %% [markdown]
# 8.Reverse a list of transaction IDs using reverse().

# %%
transaction_ids = [123, 345, 567, 789, 900]
transaction_ids.reverse()
transaction_ids
# Out:
# [900, 789, 567, 345, 123]

# %% [markdown]
# 9. Sort a list of account balances in ascending order using sort().

# %%
balances = [85000, 120000, 350000, 95000, 250000]
balances.sort()
balances
# Out:
# [85000, 95000, 120000, 250000, 350000]

# %% [markdown]
# 10. Sort a list of customer names in descending order using sort().

# %%
customers = ["Rahul", "Anita", "Kiran", "Sneha", "Vikram"]
customers.sort(reverse=True)
customers
# Out:
# ['Vikram', 'Sneha', 'Rahul', 'Kiran', 'Anita']

# %% [markdown]
# 11.Make a copy of a list using copy() and verify that modifying the copied list does not affect the original list.

# %%
customers = ["Rahul", "Anita", "Kiran", "Sneha", "Vikram"]
copycustomers=customers.copy()
copycustomers[2]="veeeenuuu"
print(copycustomers)
print(customers)
# Out:
# ['Rahul', 'Anita', 'veeeenuuu', 'Sneha', 'Vikram']
# ['Rahul', 'Anita', 'Kiran', 'Sneha', 'Vikram']

# %% [markdown]
# 12. Clear all elements from a list using clear().

# %%
balances = [85000, 65000, 15000, 120000, 52000]
balances.clear()
balances
# Out:
# []

# %% [markdown]
# 13. Append a nested list containing a new customer's details to an existing customer list.

# %%
customer = [["C101", "Rahul", "saving", 85000],
            ["C102", "Anita", "Current", 152000],
            ["C103", "Kiran", "Loan", 500000]]
New_customer = ["D101", "Neha", "Savings", 60000]
customer.append(New_customer)
customer
# Out:
# [['C101', 'Rahul', 'saving', 85000],
#  ['C102', 'Anita', 'Current', 152000],
#  ['C103', 'Kiran', 'Loan', 500000],
#  ['D101', 'Neha', 'Savings', 60000]]

# %% [markdown]
# 14.Extend a list of branch names with another list of new branches.

# %%
branches = ['c101','c102','c103']
new_branch = ['y101','y102','y103']
branches.extend(new_branch)
branches
# Out:
# ['c101', 'c102', 'c103', 'y101', 'y102', 'y103']

# %% [markdown]
# 15.Remove the first occurrence of the balance 50000 from a list using remove().

# %%
balances = [85000,50000,120000,50000,45000, 95000, 275000]
balances.remove(50000)
balances
# Out:
# [85000, 120000, 50000, 45000, 95000, 275000]

# %% [markdown]
# 16.Pop the element at index 2 from a list and print the removed value.

# %%
bank_branches = ["MG Road", "Indiranagar", "Whitefield", "Electronic City"]
bank_branches.pop(3)
bank_branches
# Out:
# ['MG Road', 'Indiranagar', 'Whitefield']

# %% [markdown]
# 17.Count how many times the city "Bangalore" appears in a list

# %%
cities = ["Bangalore", "Hyderabad", "Chennai", "Pune","Bangalore"]
cities.count("Bangalore")
# Out:
# 2

# %% [markdown]
# 18.Reverse a list of bank names and print the result.

# %%
bank_branches_names = ["MG Road", "Indiranagar", "Whitefield", "Electronic City"]
bank_branches_names.reverse()
bank_branches_names
# Out:
# ['Electronic City', 'Whitefield', 'Indiranagar', 'MG Road']

# %% [markdown]
# 19.Create a list of loan amounts and sort it in descending order.

# %%
loan_amount = [85000, 120000, 45000, 95000, 275000]
loan_amount.sort(reverse=True)
loan_amount
# Out:
# [275000, 120000, 95000, 85000, 45000]

# %% [markdown]
# 20.Insert a new customer at the beginning of a customer list using insert()

# %%
customer = ["Rahul", "Anita", "Kiran", "Sneha", "Vikram"]
customer.insert(0,"Neha")
customer
# Out:
# ['Neha', 'Rahul', 'Anita', 'Kiran', 'Sneha', 'Vikram']
